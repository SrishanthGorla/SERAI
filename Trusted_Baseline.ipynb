# %% [markdown]
# <a href="https://colab.research.google.com/github/SrishanthGorla/SERAI/blob/main/Trusted_Baseline.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import sklearn

from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression

from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    classification_report,
    confusion_matrix
)

print("Libraries imported successfully")
print("Scikit-learn version:", sklearn.__version__)
# Out:
# Libraries imported successfully
# Scikit-learn version: 1.6.1

# %%
# Load the Iris dataset
iris = load_iris()

X = pd.DataFrame(
    iris.data,
    columns=iris.feature_names
)

y = pd.Series(
    iris.target,
    name="target"
)

print("Dataset loaded successfully")
print("Dataset shape:", X.shape)
print("Number of labels:", len(y))
# Out:
# Dataset loaded successfully
# Dataset shape: (150, 4)
# Number of labels: 150

# %%
print("First 5 rows:")
display(X.head())

print("\nFeature names:")
for feature in iris.feature_names:
    print("-", feature)

print("\nTarget classes:")
for i, name in enumerate(iris.target_names):
    print(i, "=", name)
# Out:
# First 5 rows:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
# Feature names:
# - sepal length (cm)
# - sepal width (cm)
# - petal length (cm)
# - petal width (cm)
#
# Target classes:
# 0 = setosa
# 1 = versicolor
# 2 = virginica

# %%
print("===== DATASET SUMMARY =====")

print("Number of samples:", X.shape[0])
print("Number of features:", X.shape[1])
print("Number of classes:", y.nunique())

print("\nFeature data types:")
print(X.dtypes)

print("\nMissing values:")
print(X.isnull().sum())

print("\nTotal missing values:", X.isnull().sum().sum())
# Out:
# ===== DATASET SUMMARY =====
# Number of samples: 150
# Number of features: 4
# Number of classes: 3
#
# Feature data types:
# sepal length (cm)    float64
# sepal width (cm)     float64
# petal length (cm)    float64
# petal width (cm)     float64
# dtype: object
#
# Missing values:
# sepal length (cm)    0
# sepal width (cm)     0
# petal length (cm)    0
# petal width (cm)     0
# dtype: int64
#
# Total missing values: 0

# %%
class_counts = y.value_counts().sort_index()

print("===== CLASS DISTRIBUTION =====")

for class_id, count in class_counts.items():
    print(
        f"{class_id} - {iris.target_names[class_id]}: {count} samples"
    )
# Out:
# ===== CLASS DISTRIBUTION =====
# 0 - setosa: 50 samples
# 1 - versicolor: 50 samples
# 2 - virginica: 50 samples

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.20,
    random_state=42,
    stratify=y
)

print("===== TRAIN / TEST SPLIT =====")

print("Training samples:", len(X_train))
print("Testing samples:", len(X_test))

print("\nTraining class distribution:")
print(y_train.value_counts().sort_index())

print("\nTesting class distribution:")
print(y_test.value_counts().sort_index())
# Out:
# ===== TRAIN / TEST SPLIT =====
# Training samples: 120
# Testing samples: 30
#
# Training class distribution:
# target
# 0    40
# 1    40
# 2    40
# Name: count, dtype: int64
#
# Testing class distribution:
# target
# 0    10
# 1    10
# 2    10
# Name: count, dtype: int64

# %%
scaler = StandardScaler()

X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

print("Feature scaling completed.")
# Out:
# Feature scaling completed.

# %%
model = LogisticRegression(
    max_iter=200,
    random_state=42
)

model.fit(X_train_scaled, y_train)

print("Baseline Logistic Regression model trained successfully.")
# Out:
# Baseline Logistic Regression model trained successfully.

# %%
y_pred = model.predict(X_test_scaled)

print("Predictions generated successfully.")
print("Number of predictions:", len(y_pred))
# Out:
# Predictions generated successfully.
# Number of predictions: 30

# %%
accuracy = accuracy_score(y_test, y_pred)

precision = precision_score(
    y_test,
    y_pred,
    average="weighted"
)

recall = recall_score(
    y_test,
    y_pred,
    average="weighted"
)

f1 = f1_score(
    y_test,
    y_pred,
    average="weighted"
)

print("===== BASELINE MODEL PERFORMANCE =====")

print(f"Accuracy : {accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall   : {recall:.4f}")
print(f"F1-Score : {f1:.4f}")
# Out:
# ===== BASELINE MODEL PERFORMANCE =====
# Accuracy : 0.9333
# Precision: 0.9333
# Recall   : 0.9333
# F1-Score : 0.9333

# %%
print("===== CLASSIFICATION REPORT =====")

print(
    classification_report(
        y_test,
        y_pred,
        target_names=iris.target_names
    )
)
# Out:
# ===== CLASSIFICATION REPORT =====
#               precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00        10
#   versicolor       0.90      0.90      0.90        10
#    virginica       0.90      0.90      0.90        10
#
#     accuracy                           0.93        30
#    macro avg       0.93      0.93      0.93        30
# weighted avg       0.93      0.93      0.93        30

# %%
cm = confusion_matrix(y_test, y_pred)

print("===== CONFUSION MATRIX =====")
print(cm)
# Out:
# ===== CONFUSION MATRIX =====
# [[10  0  0]
#  [ 0  9  1]
#  [ 0  1  9]]

# %%
print("===== DATASET PROVENANCE =====")

print("Dataset: Iris")
print("Source: scikit-learn built-in Iris dataset")
print("Original dataset: Fisher's Iris dataset")
print("Dataset size: 150 samples")
print("Features: 4")
print("Classes: 3")
print("Missing values: 0")
print("Dataset accessed through scikit-learn:", sklearn.__version__)

print("\n===== BASELINE CONFIGURATION =====")
print("Train/Test split: 80/20")
print("Random state: 42")
print("Split method: Stratified")
print("Preprocessing: StandardScaler")
print("Classifier: Logistic Regression")
# Out:
# ===== DATASET PROVENANCE =====
# Dataset: Iris
# Source: scikit-learn built-in Iris dataset
# Original dataset: Fisher's Iris dataset
# Dataset size: 150 samples
# Features: 4
# Classes: 3
# Missing values: 0
# Dataset accessed through scikit-learn: 1.6.1
#
# ===== BASELINE CONFIGURATION =====
# Train/Test split: 80/20
# Random state: 42
# Split method: Stratified
# Preprocessing: StandardScaler
# Classifier: Logistic Regression

# %%
summary = pd.DataFrame({
    "Metric": [
        "Dataset Samples",
        "Features",
        "Classes",
        "Missing Values",
        "Training Samples",
        "Testing Samples",
        "Accuracy",
        "Precision",
        "Recall",
        "F1-Score"
    ],
    "Value": [
        X.shape[0],
        X.shape[1],
        y.nunique(),
        X.isnull().sum().sum(),
        len(X_train),
        len(X_test),
        round(accuracy, 4),
        round(precision, 4),
        round(recall, 4),
        round(f1, 4)
    ]
})

display(summary)
# Out:
#              Metric     Value
# 0   Dataset Samples  150.0000
# 1          Features    4.0000
# 2           Classes    3.0000
# 3    Missing Values    0.0000
# 4  Training Samples  120.0000
# 5   Testing Samples   30.0000
# 6          Accuracy    0.9333
# 7         Precision    0.9333
# 8            Recall    0.9333
# 9          F1-Score    0.9333
